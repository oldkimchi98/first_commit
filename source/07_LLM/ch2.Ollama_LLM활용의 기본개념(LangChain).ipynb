# %%
from IPython.display import display, HTML

display(HTML("""
<style>

/* =========================
   전체 레이아웃
========================= */

div.container{
    width:85% !important;
}

div.cell.code_cell.rendered{
    width:100%;
}

div.input_prompt{
    padding:0;
}

div.prompt{
    min-width:70px;
}

div#toc-wrapper{
    padding-top:120px;
}

table.dataframe{
    font-size:12px;
}

/* =========================
   코드 입력창
========================= */

div.CodeMirror{
    font-family:"마루 부리OTF 중간" !important;
    font-size:12pt !important;
    line-height:1.6;
}

/* =========================
   입력 셀
========================= */

div.input{
    font-family:"마루 부리OTF 중간" !important;
    font-size:12pt !important;
}

/* =========================
   코드 출력
========================= */

div.output{
    font-family:"마루 부리OTF 중간" !important;
    font-size:12pt !important;
}

/* =========================
   Markdown 전체
========================= */

.rendered_html{
    font-family:"마루 부리OTF 중간" !important;
    font-size:18px !important;
    line-height:1.8;
}

/* 제목 */

.rendered_html h1,
.rendered_html h2,
.rendered_html h3,
.rendered_html h4,
.rendered_html h5,
.rendered_html h6{
    font-family:"마루 부리OTF 조금굵은" !important;
}

/* 본문 */

.rendered_html p{
    font-family:"마루 부리OTF 중간" !important;
}

/* 리스트 */

.rendered_html li{
    font-family:"마루 부리OTF 중간" !important;
    padding:5px;
}

/* 인용 */

.rendered_html blockquote{
    font-family:"마루 부리OTF 중간" !important;
}

/* 표 */

.rendered_html table{
    font-family:"마루 부리OTF 중간" !important;
}

/* 코드 블록 */

.rendered_html pre,
.rendered_html code{
    font-family:"Consolas" !important;
    font-size:12pt !important;
}
table.dataframe{font-size:22px;}
table td, th{font-size:16px;}
table{ margin-left:0 !important;   /* 왼쪽 여백 0 */}
</style>
"""))
# Out:
# <style>
#
# /* =========================
#    전체 레이아웃
# ========================= */
#
# div.container{
#     width:85% !important;
# }
#
# div.cell.code_cell.rendered{
#     width:100%;
# }
#
# div.input_prompt{
#     padding:0;
# }
#
# div.prompt{
#     min-width:70px;
# }
#
# div#toc-wrapper{
#     padding-top:120px;
# }
#
# table.dataframe{
#     font-size:12px;
# }
#
# /* =========================
#    코드 입력창
# ========================= */
#
# div.CodeMirror{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:12pt !important;
#     line-height:1.6;
# }
#
# /* =========================
#    입력 셀
# ========================= */
#
# div.input{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:12pt !important;
# }
#
# /* =========================
#    코드 출력
# ========================= */
#
# div.output{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:12pt !important;
# }
#
# /* =========================
#    Markdown 전체
# ========================= */
#
# .rendered_html{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:18px !important;
#     line-height:1.8;
# }
#
# /* 제목 */
#
# .rendered_html h1,
# .rendered_html h2,
# .rendered_html h3,
# .rendered_html h4,
# .rendered_html h5,
# .rendered_html h6{
#     font-family:"마루 부리OTF 조금굵은" !important;
# }
#
# /* 본문 */
#
# .rendered_html p{
#     font-family:"마루 부리OTF 중간" !important;
# }
#
# /* 리스트 */
#
# .rendered_html li{
#     font-family:"마루 부리OTF 중간" !important;
#     padding:5px;
# }
#
# /* 인용 */
#
# .rendered_html blockquote{
#     font-family:"마루 부리OTF 중간" !important;
# }
#
# /* 표 */
#
# .rendered_html table{
#     font-family:"마루 부리OTF 중간" !important;
# }
#
# /* 코드 블록 */
#
# .rendered_html pre,
# .rendered_html code{
#     font-family:"Consolas" !important;
#     font-size:12pt !important;
# }
# table.dataframe{font-size:22px;}
# table td, th{font-size:16px;}
# table{ margin-left:0 !important;   /* 왼쪽 여백 0 */}
# </style>

# %% [markdown]
# **<font size="6" color="red">ch2. Ollama_LLM활용의 기본개념(LangChain)</font>**
#
# # 1. LLM을 활용하여 답변 생성
# ## 1) Ollama 이용한 로컬 LLM 이용
# - 성능은 GPT(open ai API), Claude같은 모델보다 떨어지나, 개념 설명을 위해 open source 모델 사용
#
# ### ollama.com 설치 → 모델 pull
# - cmd창에서 ollama pull deepseek -r1:1.5b

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model='deepseek-r1:1.5b')
result = llm.invoke('What is the capital of France?')
result # AIMessage
# content : 실제 답변
# response_metadata : 모델 실행에 대한 상세 정보 (전체소요시간; 모델로딩시간, 처리토큰수)
# Out:
# AIMessage(content='\n\nThe capital of France is indeed Paris. The city of Dijon, which had a significant historical role, is not the capital. Paris, the capital of the nation, is the city where the capital is located.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-09-10T07:57:32.9420259Z', 'done': True, 'done_reason': 'stop', 'total_duration': 13070776000, 'load_duration': 5596300, 'prompt_eval_count': 10, 'prompt_eval_duration': 41811000, 'eval_count': 395, 'eval_duration': 13010263000, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'}, id='lc_run--01a08a52-3a7d-7b92-a8c8-0131b42a7e7d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 395, 'total_tokens': 405})

# %%
print(result.content)
# Out:
# The capital of France is indeed Paris. The city of Dijon, which had a significant historical role, is not the capital. Paris, the capital of the nation, is the city where the capital is located.

# %% [markdown]
# ### 모델 pull
# - ollama run llama3.2:1b
# - ollam 모델은 공식적으로 한글 지원이 안됨(llama3.1:405b 한글 지원 가능 -> llama3.2:3b 한글 지원이 일부 가능)
# - exaone 모델은 공식적으로 한글 지원 : ollama pull exaone3.5:2.4b
#
# - 모델 저장 경로 : c:\Users\내컴퓨터이름\.ollama

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke("What is the fourth dimension?")
print(result.content)
# Out:
# The concept of the fourth dimension is a fundamental idea in physics and mathematics, particularly in the theories of special and general relativity. It's a challenging topic to wrap your head around, but I'll try to break it down simply.
#
# The fourth dimension is not a dimension that you can see or touch. Instead, it's a concept that helps us understand the structure of space-time. Imagine space as a three-dimensional fabric, and time as a fourth dimension that's woven into it.
#
# In the context of physics, the fourth dimension is often referred to as "spacetime" or "the fabric of spacetime." It's a way of describing the universe as a unified, four-dimensional entity, where every event in the universe is connected and interdependent.
#
# In special relativity, Albert Einstein introduced the concept of spacetime, which is a four-dimensional manifold that combines space and time. The four dimensions of spacetime are:
#
# 1. One dimension of space (x, y, z, etc.)
# 2. One dimension of time (t)
# 3. One dimension of the fourth dimension (spacetime, which includes both space and time)
#
# Think of it like a cube. In a three-dimensional space, you can move freely in three dimensions, but you're still limited by the fourth dimension, which is the additional dimension that connects space and time.
#
# The fourth dimension is crucial in understanding phenomena like:
#
# * Time travel: if you were to travel through time, the fourth dimension would become significant. You'd need to navigate through spacetime to reach different points in time.
# * Gravity: the curvature of spacetime is what warps and bends the fabric of spacetime, which is what we experience as gravity.
# * The behavior of particles: the fourth dimension helps us understand how particles move and interact with each other in spacetime.
#
# The concept of the fourth dimension is still a topic of active research and debate in the scientific community. However, it's a fundamental idea that has far-reaching implications for our understanding of the universe and the laws of physics.
#
# To illustrate this concept, imagine a basketball player running down a court. The player's position in space (3 dimensions) is well-defined, but their position in spacetime (4 dimensions) is not. As they move, the fourth dimension becomes important, allowing them to change their trajectory and interact with the court in new ways.
#
# While the fourth dimension is a mind-bending concept, it's essential to remember that it's a mathematical construct, not a physical reality. However, it has profound implications for our understanding of the universe and the laws of physics that govern it.

# %%
result.content
# Out:
# 'The concept of the fourth dimension is a fundamental idea in physics and mathematics, particularly in the theories of special and general relativity. It\'s a challenging topic to wrap your head around, but I\'ll try to break it down simply.\n\nThe fourth dimension is not a dimension that you can see or touch. Instead, it\'s a concept that helps us understand the structure of space-time. Imagine space as a three-dimensional fabric, and time as a fourth dimension that\'s woven into it.\n\nIn the context of physics, the fourth dimension is often referred to as "spacetime" or "the fabric of spacetime." It\'s a way of describing the universe as a unified, four-dimensional entity, where every event in the universe is connected and interdependent.\n\nIn special relativity, Albert Einstein introduced the concept of spacetime, which is a four-dimensional manifold that combines space and time. The four dimensions of spacetime are:\n\n1. One dimension of space (x, y, z, etc.)\n2. One dimension of time (t)\n3. One dimension of the fourth dimension (spacetime, which includes both space and time)\n\nThink of it like a cube. In a three-dimensional space, you can move freely in three dimensions, but you\'re still limited by the fourth dimension, which is the additional dimension that connects space and time.\n\nThe fourth dimension is crucial in understanding phenomena like:\n\n* Time travel: if you were to travel through time, the fourth dimension would become significant. You\'d need to navigate through spacetime to reach different points in time.\n* Gravity: the curvature of spacetime is what warps and bends the fabric of spacetime, which is what we experience as gravity.\n* The behavior of particles: the fourth dimension helps us understand how particles move and interact with each other in spacetime.\n\nThe concept of the fourth dimension is still a topic of active research and debate in the scientific community. However, it\'s a fundamental idea that has far-reaching implications for our understanding of the universe and the laws of physics.\n\nTo illustrate this concept, imagine a basketball player running down a court. The player\'s position in space (3 dimensions) is well-defined, but their position in spacetime (4 dimensions) is not. As they move, the fourth dimension becomes important, allowing them to change their trajectory and interact with the court in new ways.\n\nWhile the fourth dimension is a mind-bending concept, it\'s essential to remember that it\'s a mathematical construct, not a physical reality. However, it has profound implications for our understanding of the universe and the laws of physics that govern it.'

# %%
result = llm.invoke('지평좌표계는 왜 고정되어있나요?')
result.content
# Out:
# '지평 좌표계는 고정되어있은 이유는 여러 가지 때문입니다.\n\n1. **위치의 구체화**: 지평 좌표계는 지형을 구체적으로 분리할 수 있는 수치로, 대다수地図는 위치에서 구체적으로 분리할 수 없기 때문에 지평 좌표계가 고정되어있을 수 있습니다.\n2. **위치의 특성**: 지평 좌표계는 위치의 특성을 부여할 수 있어, 지형의 특성 such as 고 nguyên점, 고점, 고선, 등이 명확하게 분리할 수 있습니다.\n3. **위치의 가치**: 지평 좌표계는 위치의 가치로, 지형의 주제가 되는 지점을 고정할 수 있어, 지평 좌표계가 고정되어있을 수 있습니다.\n4. **위치의 불일치**: 지평 좌표계는 위치의 불일치가 발생할 수 있기 때문에, 지형을 고정할 수 있어, 지평 좌표계가 고정되어있을 수 있습니다.\n\n이러한 이유가 있ため, 지평 좌표계는 고정되어있으며, 지형의 특성을 명확하게 분리할 수 있어, 지형을 정확하게 묘사할 수 있습니다.'

# %%
result = llm.invoke('귀신은 지평좌표계를 어떻게 고정하나요?')
result.content
# Out:
# '지평좌표계는 지평선의 개념에 따라 다르며, 일반적으로 지평선의 개념은 지평선의 개념을 사용하여 지평선의 위치를 고정하는 방법에 따라서 다르다.\n\n1. **지평선의 개념**: 지평선은 지평선의 개념에 따라 다르며, 일반적으로 지평선은 지평선의 개념에 따라 지평선의 위치를 고정하는 방법에 따라서 다르다.\n\n2. **시각적 지평좌표계**: 시각적 지평좌표계는 지평선의 개념에 따라 다르며, 일반적으로 지평선의 개념에 따라 지평선의 위치를 고정하는 방법에 따라서 다르다. 이ระบบ에서는 지평선의 위치를 고정하기위한 지평선의 개념은 지평선의 개념에 따라 다르며, 일반적으로 지평선의 개념에 따라 지평선의 위치를 고정하는 방법에 따라서 다르다.\n\n3. **지리적 지평좌표계**: 지리적 지평좌표계는 지평선의 개념에 따라 다르며, 일반적으로 지평선의 개념에 따라 지평선의 위치를 고정하는 방법에 따라서 다르다. 이ระบบ에서는 지평선의 위치를 고정하기위한 지평선의 개념은 지평선의 개념에 따라 다르며, 일반적으로 지평선의 개념에 따라 지평선의 위치를 고정하는 방법에 따라서 다르다.\n\n4. **물리적 지평좌표계**: 물리적 지평좌표계는 지평선의 개념에 따라 다르며, 일반적으로 지평선의 개념에 따라 지평선의 위치를 고정하는 방법에 따라서 다르다. 이ระบบ에서는 지평선의 위치를 고정하기위한 지평선의 개념은 지평선의 개념에 따라 다르며, 일반적으로 지평선의 개념에 따라 지평선의 위치를 고정하는 방법에 따라서 다르다.\n\n5. **시사 지평좌표계**: 시사 지평좌표계는 지평선의 개념에 따라 다르며, 일반적으로 지평선의 개념에 따라 지평선의 위치를 고정하는 방법에 따라서 다르다. 이ระบบ에서는 지평선의 위치를 고정하기위한 지평선의 개념은 지평선의 개념에 따라 다르며, 일반적으로 지평선의 개념에 따라 지평선의 위치를 고정하는 방법에 따라서 다르다.'

# %% [markdown]
# ## 2) openai 모델 활용
# - pip install langchain-openai

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4.1-nano")
result = llm.invoke('How do ghosts get fixed in a Cartesian coordinate system?')
# result = llm.invoke('귀신은 어떻게 지평좌표계를 고정하니?')
result.content
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from langchain_openai import ChatOpenAI
#       2 llm = ChatOpenAI(model="gpt-4.1-nano")
#       3 result = llm.invoke('How do ghosts get fixed in a Cartesian coordinate system?')
#
# ModuleNotFoundError: No module named 'langchain_openai'
