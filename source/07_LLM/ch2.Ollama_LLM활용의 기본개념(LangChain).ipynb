# %%
from IPython.display import display, HTML

display(HTML("""
<style>

/* =========================
전체 레이아웃
========================= */

div.container{
    width:85% !important;
}

div.cell.code_cell.rendered{
    width:100%;
}

div.input_prompt{
    padding:0;
}

div.prompt{
    min-width:70px;
}

div#toc-wrapper{
    padding-top:120px;
}

table.dataframe{
    font-size:12px;
}

/* =========================
   코드 입력창
========================= */

div.CodeMirror{
    font-family:"마루 부리OTF 중간" !important;
    font-size:12pt !important;
    line-height:1.6;
}

/* =========================
   입력 셀
========================= */

div.input{
    font-family:"마루 부리OTF 중간" !important;
    font-size:12pt !important;
}

/* =========================
   코드 출력
========================= */

div.output{
    font-family:"마루 부리OTF 중간" !important;
    font-size:12pt !important;
}

/* =========================
   Markdown 전체
========================= */

.rendered_html{
    font-family:"마루 부리OTF 중간" !important;
    font-size:18px !important;
    line-height:1.8;
}

/* 제목 */

.rendered_html h1,
.rendered_html h2,
.rendered_html h3,
.rendered_html h4,
.rendered_html h5,
.rendered_html h6{
    font-family:"마루 부리OTF 조금굵은" !important;
}

/* 본문 */

.rendered_html p{
    font-family:"마루 부리OTF 중간" !important;
}

/* 리스트 */

.rendered_html li{
    font-family:"마루 부리OTF 중간" !important;
    padding:5px;
}

/* 인용 */

.rendered_html blockquote{
    font-family:"마루 부리OTF 중간" !important;
}

/* 표 */

.rendered_html table{
    font-family:"마루 부리OTF 중간" !important;
}

/* 코드 블록 */

.rendered_html pre,
.rendered_html code{
    font-family:"Consolas" !important;
    font-size:12pt !important;
}
table.dataframe{font-size:22px;}
table td, th{font-size:16px;}
table{ margin-left:0 !important;   /* 왼쪽 여백 0 */}
</style>
"""))
# Out:
# <style>
#
# /* =========================
# 전체 레이아웃
# ========================= */
#
# div.container{
#     width:85% !important;
# }
#
# div.cell.code_cell.rendered{
#     width:100%;
# }
#
# div.input_prompt{
#     padding:0;
# }
#
# div.prompt{
#     min-width:70px;
# }
#
# div#toc-wrapper{
#     padding-top:120px;
# }
#
# table.dataframe{
#     font-size:12px;
# }
#
# /* =========================
#    코드 입력창
# ========================= */
#
# div.CodeMirror{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:12pt !important;
#     line-height:1.6;
# }
#
# /* =========================
#    입력 셀
# ========================= */
#
# div.input{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:12pt !important;
# }
#
# /* =========================
#    코드 출력
# ========================= */
#
# div.output{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:12pt !important;
# }
#
# /* =========================
#    Markdown 전체
# ========================= */
#
# .rendered_html{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:18px !important;
#     line-height:1.8;
# }
#
# /* 제목 */
#
# .rendered_html h1,
# .rendered_html h2,
# .rendered_html h3,
# .rendered_html h4,
# .rendered_html h5,
# .rendered_html h6{
#     font-family:"마루 부리OTF 조금굵은" !important;
# }
#
# /* 본문 */
#
# .rendered_html p{
#     font-family:"마루 부리OTF 중간" !important;
# }
#
# /* 리스트 */
#
# .rendered_html li{
#     font-family:"마루 부리OTF 중간" !important;
#     padding:5px;
# }
#
# /* 인용 */
#
# .rendered_html blockquote{
#     font-family:"마루 부리OTF 중간" !important;
# }
#
# /* 표 */
#
# .rendered_html table{
#     font-family:"마루 부리OTF 중간" !important;
# }
#
# /* 코드 블록 */
#
# .rendered_html pre,
# .rendered_html code{
#     font-family:"Consolas" !important;
#     font-size:12pt !important;
# }
# table.dataframe{font-size:22px;}
# table td, th{font-size:16px;}
# table{ margin-left:0 !important;   /* 왼쪽 여백 0 */}
# </style>

# %% [markdown]
# **<font size="6" color="red">ch2. Ollama_LLM활용의 기본개념(LangChain)</font>**
#
# # 1. LLM을 활용하여 답변 생성
# ## 1) Ollama 이용한 로컬 LLM 이용
# - 성능은 GPT(open ai API), Claude같은 모델보다 떨어지나, 개념 설명을 위해 open source 모델 사용
#
# ### ollama.com 설치 → 모델 pull
# - cmd창에서 ollama pull deepseek -r1:1.5b

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model='deepseek-r1:1.5b')
result = llm.invoke('What is the capital of France?')
result # AIMessage
# content : 실제 답변
# response_metadata : 모델 실행에 대한 상세 정보 (전체소요시간; 모델로딩시간, 처리토큰수)
# Out:
# AIMessage(content='\n\nThe capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-09-11T03:35:08.1684999Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2352153200, 'load_duration': 1900283900, 'prompt_eval_count': 10, 'prompt_eval_duration': 112302000, 'eval_count': 12, 'eval_duration': 330529000, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'}, id='lc_run--01a08e88-8155-7662-ba86-c48fb449ed12-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 12, 'total_tokens': 22})

# %%
print(result.content)
# Out:
# The capital of France is Paris.

# %% [markdown]
# ### 모델 pull
# - ollama run llama3.2:1b
# - ollam 모델은 공식적으로 한글 지원이 안됨(llama3.1:405b 한글 지원 가능 -> llama3.2:3b 한글 지원이 일부 가능)
# - exaone 모델은 공식적으로 한글 지원 : ollama pull exaone3.5:2.4b
#
# - 모델 저장 경로 : c:\Users\내컴퓨터이름\.ollama

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b",
                temperature=0.2,
                top_k=40,
                top_p=0.9,
                # num_ctx=4096 # 컨텍스트 윈도우(입력토큰과 출력토큰
                )
result = llm.invoke("What is the fourth dimension?")
print(result.content)
# Out:
# The fourth dimension is a concept in physics and mathematics that is often misunderstood or misinterpreted. I'll try to break it down in a way that's easy to understand.
#
# The fourth dimension is not a physical dimension like the three we're familiar with (length, width, and depth). Instead, it's a way of describing time as a separate dimension.
#
# In classical physics, we experience time as a linear concept, where past, present, and future are intertwined. However, some theories, such as Einstein's theory of relativity, suggest that time is not a fixed, one-way dimension. Instead, it's a dimension that's intertwined with space, and we can move through it in different ways.
#
# Imagine a three-dimensional space, like a cube. Each point in this space has three coordinates: x, y, and z. Time, on the other hand, is more like a fourth dimension. It's a dimension that allows us to move through time, but it's not a separate, independent dimension like the others.
#
# Think of it like this: if you're standing still in a room, you're in the same point in space (x, y, z coordinates). But if you move to the next room, you're now in a different point in space (x, y, z coordinates). Now, imagine that you're standing still in the next room, and then you move to the room across the hall. You're now in a different point in space (x, y, z coordinates), but you're still in the same point in time (the same moment in the past or future).
#
# This idea of time as a fourth dimension is often represented graphically using four-dimensional space. Imagine a cube with four dimensions: three for space (x, y, z) and one for time (t). This is similar to the way we experience time in our everyday lives, but it's a more abstract concept.
#
# The fourth dimension is still a topic of debate among physicists and mathematicians, and there's ongoing research to better understand its properties and implications. However, one thing is clear: the concept of time as a fourth dimension is a fundamental aspect of modern physics and has the potential to revolutionize our understanding of the universe.

# %%
result.content
# Out:
# "The fourth dimension is a concept in physics and mathematics that is often misunderstood or misinterpreted. I'll try to break it down in a way that's easy to understand.\n\nThe fourth dimension is not a physical dimension like the three we're familiar with (length, width, and depth). Instead, it's a way of describing time as a separate dimension.\n\nIn classical physics, we experience time as a linear concept, where past, present, and future are intertwined. However, some theories, such as Einstein's theory of relativity, suggest that time is not a fixed, one-way dimension. Instead, it's a dimension that's intertwined with space, and we can move through it in different ways.\n\nImagine a three-dimensional space, like a cube. Each point in this space has three coordinates: x, y, and z. Time, on the other hand, is more like a fourth dimension. It's a dimension that allows us to move through time, but it's not a separate, independent dimension like the others.\n\nThink of it like this: if you're standing still in a room, you're in the same point in space (x, y, z coordinates). But if you move to the next room, you're now in a different point in space (x, y, z coordinates). Now, imagine that you're standing still in the next room, and then you move to the room across the hall. You're now in a different point in space (x, y, z coordinates), but you're still in the same point in time (the same moment in the past or future).\n\nThis idea of time as a fourth dimension is often represented graphically using four-dimensional space. Imagine a cube with four dimensions: three for space (x, y, z) and one for time (t). This is similar to the way we experience time in our everyday lives, but it's a more abstract concept.\n\nThe fourth dimension is still a topic of debate among physicists and mathematicians, and there's ongoing research to better understand its properties and implications. However, one thing is clear: the concept of time as a fourth dimension is a fundamental aspect of modern physics and has the potential to revolutionize our understanding of the universe."

# %%
result = llm.invoke('지평좌표계는 왜 고정되어있나요?')
result.content
# Out:
# '지평좌표계는 고정되어있는 이유는 다음과 같습니다.\n\n1. **역학적 이유**: 지평좌표계는 고정되어있는 이유는 역학적 이유가 있습니다. 지평은 지구의 표면을 반사하는 역학적 특성에 의해 고정되어있으며, 이 특성은 지평의 수직 방향이 지구의 표면에서 반사되는 방향에 따라 고정되어있기 때문입니다.\n2. **역학적 특성**: 지평의 수직 방향은 지구의 표면에서 반사되는 방향에 따라 고정되어있으며, 이 특성은 지평의 수직 방향이 지구의 표면에서 반사되는 방향에 따라 고정되어있기 때문입니다.\n3. **역학적 특성**: 지평의 수직 방향은 지구의 표면에서 반사되는 방향에 따라 고정되어있으며, 이 특성은 지평의 수직 방향이 지구의 표면에서 반사되는 방향에 따라 고정되어있기 때문입니다.\n4. **역학적 특성**: 지평의 수직 방향은 지구의 표면에서 반사되는 방향에 따라 고정되어있으며, 이 특성은 지평의 수직 방향이 지구의 표면에서 반사되는 방향에 따라 고정되어있기 때문입니다.\n\n이러한 역학적 이유로, 지평좌표계는 고정되어있으며, 고정된 지평 좌표는 고정된 지구 표면의 수직 방향에 따라 고정되어있기 때문입니다.'

# %%
result = llm.invoke('귀신은 지평좌표계를 어떻게 고정하나요?')
result.content
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 result = llm.invoke('귀신은 지평좌표계를 어떻게 고정하나요?')
#       2 result.content
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)
#     481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
#     492                 tags=config.get("tags"),
#     493                 metadata=config.get("metadata"),
#     494                 run_name=config.get("run_name"),
#     495                 run_id=config.pop("run_id", None),
#     496                 **kwargs,
#     497             ).generations[0][0],
#     498         ).message,
#     499     )
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_core\language_models\chat_models.py:1877, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1868 @override
#    1869 def generate_prompt(
#    1870     self,
#    (...)
#    1874     **kwargs: Any,
#    1875 ) -> LLMResult:
#    1876     prompt_messages = [p.to_messages() for p in prompts]
# -> 1877     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_core\language_models\chat_models.py:1684, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1681 for i, m in enumerate(input_messages):
#    1682     try:
#    1683         results.append(
# -> 1684             self._generate_with_cache(
#    1685                 m,
#    1686                 stop=stop,
#    1687                 run_manager=run_managers[i] if run_managers else None,
#    1688                 **kwargs,
#    1689             )
#    1690         )
#    1691     except BaseException as e:
#    1692         if run_managers:
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_core\language_models\chat_models.py:2022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2020     result = generate_from_stream(iter(chunks))
#    2021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2022     result = self._generate(
#    2023         messages, stop=stop, run_manager=run_manager, **kwargs
#    2024     )
#    2025 else:
#    2026     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_ollama\chat_models.py:1200, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#    1193 def _generate(
#    1194     self,
#    1195     messages: list[BaseMessage],
#    (...)
#    1198     **kwargs: Any,
#    1199 ) -> ChatResult:
# -> 1200     final_chunk = self._chat_stream_with_aggregation(
#    1201         messages, stop, run_manager, verbose=self.verbose, **kwargs
#    1202     )
#    1203     generation_info = final_chunk.generation_info
#    1204     chat_generation = ChatGeneration(
#    1205         message=AIMessage(
#    1206             content=final_chunk.text,
#    (...)
#    1213         generation_info=generation_info,
#    1214     )
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_ollama\chat_models.py:1135, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#    1126 def _chat_stream_with_aggregation(
#    1127     self,
#    1128     messages: list[BaseMessage],
#    (...)
#    1132     **kwargs: Any,
#    1133 ) -> ChatGenerationChunk:
#    1134     final_chunk = None
# -> 1135     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#    1136         if final_chunk is None:
#    1137             final_chunk = chunk
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_ollama\chat_models.py:1224, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1217 def _iterate_over_stream(
#    1218     self,
#    1219     messages: list[BaseMessage],
#    1220     stop: list[str] | None = None,
#    1221     **kwargs: Any,
#    1222 ) -> Iterator[ChatGenerationChunk]:
#    1223     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1224     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1225         if not isinstance(stream_resp, str):
#    1226             content = (
#    1227                 stream_resp["message"]["content"]
#    1228                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1229                 else ""
#    1230             )
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_ollama\chat_models.py:1122, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#    1119 chat_params = self._chat_params(messages, stop, **kwargs)
#    1121 if chat_params["stream"]:
# -> 1122     yield from self._client.chat(**chat_params)
#    1123 else:
#    1124     yield self._client.chat(**chat_params)
#
# File ~\anaconda3\envs\llm\lib\site-packages\ollama\_client.py:191, in Client._request.<locals>.inner()
#     188   e.response.read()
#     189   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 191 for line in r.iter_lines():
#     192   part = json.loads(line)
#     193   if err := part.get('error'):
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpx\_models.py:929, in Response.iter_lines(self)
#     927 decoder = LineDecoder()
#     928 with request_context(request=self._request):
# --> 929     for text in self.iter_text():
#     930         for line in decoder.decode(text):
#     931             yield line
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpx\_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\anaconda3\envs\llm\lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2) openai 모델 활용
# - pip install langchain-openai

# %%
# 환경변수('OPENAI_API_KEY' or 'OPENAI_ADMIN_KEY' enviroment variable)
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
# !pip install langchain-openai

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4.1-nano",
                # api_key=os.getenv('OPENAI_API_KEY')
                )
result = llm.invoke('What is the capital of Korea?')
# result = llm.invoke('한국의 수도가 어디예요?')
result.content
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 from langchain_openai import ChatOpenAI
# ----> 2 llm = ChatOpenAI(model="gpt-4.1-nano",
#       3                 # api_key=os.getenv('OPENAI_API_KEY')
#       4                 )
#       5 result = llm.invoke('What is the capital of Korea?')
#       6 # result = llm.invoke('한국의 수도가 어디예요?')
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_core\load\serializable.py:136, in Serializable.__init__(self, *args, **kwargs)
#     134 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135     """"""  # noqa: D419  # Intentional blank docstring
# --> 136     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_openai\chat_models\base.py:1465, in BaseChatOpenAI.validate_environment(self)
#    1451         self.http_async_client = _build_proxied_async_httpx_client(
#    1452             proxy=self.openai_proxy,
#    1453             verify=global_ssl_context,
#    1454             socket_options=resolved_socket_options,
#    1455         )
#    1456     async_specific = {
#    1457         "http_client": self.http_async_client
#    1458         or _get_default_async_httpx_client(
#    (...)
#    1463         "api_key": async_api_key_value,
#    1464     }
# -> 1465     self.root_async_client = openai.AsyncOpenAI(
#    1466         **client_params,
#    1467         **async_specific,  # type: ignore[arg-type]
#    1468     )
#    1469     self.async_client = self.root_async_client.chat.completions
#    1470 return self
#
# File ~\anaconda3\envs\llm\lib\site-packages\openai\_client.py:1027, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, data_residency, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#    1017 self.admin_api_key = admin_api_key if provider_runtime is None else None
#    1019 if (
#    1020     provider_runtime is None
#    1021     and _enforce_credentials
#    (...)
#    1025     and self.admin_api_key is None
#    1026 ):
# -> 1027     raise OpenAIError(
#    1028         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#    1029     )
#    1031 if organization is None and provider_runtime is None:
#    1032     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
from langchain_a import ChatOpenAI
llm = ChatAnthropic(model='claude-haiku-4-5-20251001')
# ANTHROPIC_API_KEY environment variable
# LLM.invoke('What is the capital of korea?')

# %% [markdown]
# # 2. 랭체인 스타일로 프롬포트 작성하기
# - 프롬프트 : llm호출시 쓰는 질문
# ## 1) 기본 프롬프트 템플릿 사용
# - PromptTemplate 을 사용하여 변수가 포함된 템플릿 작성하면 PromptValue를 만들 수 있다

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model='llama3.2:1b')
# llm.invoke('What is the captial of korea?')
llm.invoke("What is the captial of korea?")
# 프롬포트 가능 타입 : str, PromptValue, list of BaseMessages
# Out:
# AIMessage(content='The capital of Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-11T03:37:41.5656498Z', 'done': True, 'done_reason': 'stop', 'total_duration': 491428000, 'load_duration': 6185100, 'prompt_eval_count': 34, 'prompt_eval_duration': 172856000, 'eval_count': 8, 'eval_duration': 284252000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08e8a-dfd0-7670-87ae-3b127a60ed8d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 34, 'output_tokens': 8, 'total_tokens': 42})

# %%
from langchain_core.prompts import PromptTemplate
prompt_template = PromptTemplate(
                                  template="what is the capital of {country}?", # {}안에 값을 새로운 값으로 대체
                                  input_variables = ['country']
)
prompt = prompt_template.invoke({"country":"Korea"})
print(1, prompt)
prompt = prompt_template.invoke("Korea")
print(2, prompt)
llm.invoke(prompt)
# Out:
# 1 text='what is the capital of Korea?'
# 2 text='what is the capital of Korea?'
# AIMessage(content='The capital of Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-11T03:37:42.1022706Z', 'done': True, 'done_reason': 'stop', 'total_duration': 424812600, 'load_duration': 6687400, 'prompt_eval_count': 32, 'prompt_eval_duration': 149321000, 'eval_count': 8, 'eval_duration': 264879000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08e8a-e22d-7dd0-8186-e3cb4507accd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 8, 'total_tokens': 40})

# %%
country = input('수도를 알고 싶은 나라는(영어)? ')
llm.invoke(prompt_template.invoke(country))
# Out:
# 수도를 알고 싶은 나라는(영어)?
# AIMessage(content="You're looking for the capital of a specific country or region. Can you please provide more context or information about the location you're interested in?", additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-11T03:37:43.599611Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1198943500, 'load_duration': 6719300, 'prompt_eval_count': 31, 'prompt_eval_duration': 102586000, 'eval_count': 30, 'eval_duration': 1084767000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08e8a-e4ff-74e0-ad0d-92ccd3ac6aa1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 30, 'total_tokens': 61})

# %%
def answer(country):
    '나라명을 입력받아 llm에게 수도명을 받아 return'
    from langchain_ollama import ChatOllama
    from langchain_core.prompts import PromptTemplate
    llm = ChatOllama(model='llama3.2:1b')
    prompt_template = PromptTemplate(
                                        template='What is the capital of {country}?',
                                        input_variables = ['country']
    )
    result = llm.invoke(prompt_template.invoke(country) )
    return result.content

# %%
country = input("수도를 알고 싶은 나라는(영어)>")
answer(country)
# Out:
# 수도를 알고 싶은 나라는(영어)>
# "Could you please specify which country or region you're asking about? I'll do my best to provide the correct capital."

# %% [markdown]
# ## 2) 메세지 기반 프롬포트 작성
# - list of BaseMessages
# - BaseMessage 상속받은 클래스 : AIMessage, HumanMessage, SystemMessage, ToolMessage
# - [BaseMessage객체, BaseMessage객체, BaseMessage객체, ...]

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage, BaseMessage
from langchain_ollama import ChatOllama
llm = ChatOllama(model='llama3.2:1b')
message_list = [
    SystemMessage(content="You are a helpful assistant!"), # llm 페르소나
    HumanMessage(content="What is the capital of Italy"), # 질문 답변 예제(few shot)
    AIMessage(content='The capital of Italy is Rome.'),
    HumanMessage(content="What is the capital of France"), # 질문 답변 예제(few shot)
    AIMessage(content='The capital of France is Paris.'),
    HumanMessage(content='what is the capital of korea?') # llm에게 질문하고 싶은 내용
]
llm.invoke(message_list)
# Out:
# AIMessage(content='The capital of South Korea is Seoul. The capital of North Korea is Pyongyang.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-11T03:37:46.234337Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1375824200, 'load_duration': 4250000, 'prompt_eval_count': 85, 'prompt_eval_duration': 658156000, 'eval_count': 17, 'eval_duration': 708435000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08e8a-ee98-7512-ac79-55428c0259f5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 85, 'output_tokens': 17, 'total_tokens': 102})

# %% [markdown]
# ## 3) ChatPromptTemplate 사용(추천; 확장성 용이)
# - BaseMessage 리스트 → 튜플리스트

# %%
from langchain_core.prompts import ChatPromptTemplate
chatPromptTemplate = ChatPromptTemplate([
    SystemMessage(content="You are a helpful assistant!"), # llm 페르소나
    HumanMessage(content="What is the capital of Italy"), # 질문 답변 예제(few shot)
    AIMessage(content='The capital of Italy is Rome.'),
    HumanMessage(content="What is the capital of France"), # 질문 답변 예제(few shot)
    AIMessage(content='The capital of France is Paris.'),
    HumanMessage(content='what is the capital of korea?') # llm에게 질문하고 싶은 내용
])
chatPromptTemplate.imvoke({'country':'Korea'})
print('프롬포트 :', prompt)

# %%
from langchain_core.prompts import ChatPromptTemplate
chatPromptTemplate = ChatPromptTemplate([
    ("system", "You are a helpful assistant!"),
    ("human", "What is the capital of Italy?"),
    ("ai", "The capital of Italy is Rome."),
    ("human", "What is the capital of France?"),
    ("ai", "The capital of France is Paris."),
    ("human", "What is the capital of {country}?")
])
prompt = chatPromptTemplate.invoke({'country':'Korea'})
print('프롬포트 :', prompt)
# Out:
# 프롬포트 : messages=[SystemMessage(content='You are a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of Italy?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of Italy is Rome.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is the capital of France?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is the capital of Korea?', additional_kwargs={}, response_metadata={})]

# %%
llm.invoke(chatPromptTemplate.invoke({'Korea'}))
# Out:
# AIMessage(content='The capital of Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-11T03:52:05.0717143Z', 'done': True, 'done_reason': 'stop', 'total_duration': 425418100, 'load_duration': 5892000, 'prompt_eval_count': 89, 'prompt_eval_duration': 163417000, 'eval_count': 8, 'eval_duration': 252419000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08e98-0d23-7413-ae20-2644f0ccdfb4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 89, 'output_tokens': 8, 'total_tokens': 97})

# %% [markdown]
# # 3. 답변 형식 컨트롤하기
# - invoke 실행 결과 AIMessage() -> String, json 변환해주는 OutputParser 이용
#
# ## 1) 문자열 출력 파서 이용
# - StrOutputParser를 이용하여 LLM출력(AIMessage)를 단순 문자열로 변환

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
# 명시적인 지시사항이 포함된 프롬프트
prompt_template = PromptTemplate(
    template='What is the capital of {country}? Return the name of the city only.',
    input_variables = ['country']
)
# 프롬포트 템플릿에 값 주입
prompt = prompt_template.invoke({'country':'korea'})
print('프롬포트 :', prompt)
aimessage = llm.invoke(prompt)
# aimessage중 답변만 문자로 받기
output_parser = StrOutputParser()
result = output_parser.invoke(aimessage)
print('파서 결과 :', result)
# Out:
# 프롬포트 : text='What is the capital of korea? Return the name of the city only.'
# 파서 결과 : Seoul

# %%
output_parser.invoke(llm.invoke(prompt_template.invoke({'country':'Korea'} )))
output_parser.invoke(llm.invoke(prompt_template.invoke('korea')))
# Out:
# 'Seoul'

# %%
chatPromptTemplate = ChatPromptTemplate([
    ("system", "You are a helpful assistant!"),
    ("human", "What is the capital of Italy?"),
    ("ai", "The capital of Italy is Rome."),
    ("human", "What is the capital of France?"),
    ("ai", "The capital of France is Paris."),
    ("human", "What is the capital of {country}? Return the name of the city only.")
])
output_parser = StrOutputParser()
output_parser.invoke(llm.invoke(chatPromptTemplate.invoke({'country':'korea'}) ))

# %% [markdown]
# ## 2) Json 출력파서 이용
# - {'name':'홍', 'age':20 }

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser, JsonOutputParser
llm = ChatOllama(model='llama3.2:1b')
country_detail_prompt = PromptTemplate(
    template="""
    Give following information about {country}.
    - Capital
    - Population
    - Language
    - Currency
    Return ONLY a valid JSON object with no additional text
    Example format :
    {{'Capital' : 'Seoul', 'Population' : "50 million", 'Language' : 'Korean', 'Currency' : 'won' }}
    """,
    input_variables = ['country']
)
prompt = country_detail_prompt.invoke({'country' : 'France'})
aimessage = llm.invoke(prompt)
output_parser = JsonOutputParser()
result = output_parser.invoke(aimessage)
print(type(result), result)
# Out:
# <class 'dict'> {'Capital': 'Paris', 'Population': '66 million', 'Language': 'French', 'Currency': 'Euro'}

# %%
info = output_parser.invoke(llm.invoke(country_detail_prompt.invoke('France')))
info
# Out:
# {'Capital': 'Paris',
#  'Population': '67 million',
#  'Language': 'French',
#  'Currency': 'Euro'}

# %% [markdown]
# ## 3) 구조화된 객체로 반환
# - Pydantic 모델(pip install pydantic)을 사용하여 LLM출력을 구조화된 형식으로 받기(JsonParser 좀 안정적)
# - Pydantic : 데이터 유효성 검사, 설정관리를 간편하게 해주는 라이브러리

# %%
class User:
    def __init__(self, id, name, is_active=True):
        self.id = id
        self.name = name
        self.is_active = is_active
user = User('1', "홍길동")
user = User(1, "홍", "활성화됨")
print(user)
print(user.id, user.name, user.is_active)
# Out:
# <__main__.User object at 0x0000021C8A88C190>
# 1 홍 True

# %%
from pydantic import BaseModel, Field
class User(BaseModel):
    # gt=0 : id>0, lt=0 : id<0, ge=0 : id>0, le=0: id<=0
    id:int = Field(gt=0, description='id')
    name:str = Field(min_length=2, description='name')
    is_active:bool = Field(default=True, description='id활성화')
user = User(id=1, name='홍길동', is_active=True)
print(user)
# Out:
# id=1 name='홍길동' is_active=True

# %%
country_detail_prompt = PromptTemplate(
    template="""
    Give following information about {country}.
    - Capital
    - Population
    - Language
    - Currency
    Return ONLY a valid JSON object with no additional text
    Example format :
    {{'Capital' : 'Seoul', 'Population' : "50,000,000", 'Language' : 'Korean', 'Currency' : 'won' }}
    """,
    input_variables = ['country']
)
class CountryDetail(BaseModel):
    capital:str = Field(description="the capital of the country")
    population:int = Field(description="the population of the country")
    language:str = Field(description="the language of the country")
    currency:str = Field(description="the currency of the country")

# 출력파서 + llm
structedllm = llm.with_structured_output(CountryDetail)
info = structedllm.invoke(country_detail_prompt.invoke({'country':'Korea'}))
print(type(info))
print(info)
print(info.capital, info.population, info.language, info.currency)
print(info.model_dump()) # 객체를 dict로
# Out:
# <class '__main__.CountryDetail'>
# capital='Seoul' population=50 language='Korean' currency='won'
# Seoul 50 Korean won

# %%
aimessage = llm.invoke(country_detail_prompt.invoke({'country':'Korea'}))
print(aimessage.content)
# Out:
# ```
# {
#   "Capital" : "Seoul",
#   "Population" : "50,000,000",
#   "Language" : "Korean",
#   "Currency" : "won"
# }
# ```

# %% [markdown]
# # 4. LCEL(LangChain Expression Language)을 활용한 렝체인 생성
# ## 1) 문자열 출력 파서 사용
# - StrOutputParser, ChatOllama, PromptTemplate등은 모두 Runable로 상속받아 invoke가 있음

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
# 명시적인 지시사항이 포함된 프롬프트
prompt_template = PromptTemplate(
    template='What is the capital of {country}? Return the name of the city only.',
    input_variables = ['country']
)
outputParser = StrOutputParser()
outputParser.invoke(llm.invoke(prompt_template.invoke({'country':'korea'})))
# Out:
# 'Seoul'

# %% [markdown]
# ## 2) LCEL을 사용한 체인 구성
# - (|) 사용

# %%
# 프롬포트 템플릿 -> llm -> 출력파서를 연결시키는 체인 생성
capital_chain = prompt_template | llm | outputParser
# 생성된 체인 invoke
capital_chain.invoke({'country':'Korea'})
# Out:
# 'Seoul'

# %%
type(capital_chain)
# Out:
# langchain_core.runnables.base.RunnableSequence

# %% [markdown]
# ## 3) 복합 체인 구성
# - 여러 단계의 추론이 필요한 경우 (체인 연결)

# %%
# 나라 설명 -> 나라이름
country_prompt = PromptTemplate(
    template="""Guess the name of the country based on the following information: 
    {information}
    Return the name of the country only""",
    input_variables=['information']
)
outputParser.invoke(llm.invoke(country_prompt.invoke({'information':"This country is very famous for its wine"})))
# Out:
# 'Italy'

# %%
# 나라명 추측 체인
country_chain = country_prompt | llm | outputParser
country_chain.invoke({'information':'This country is very famous for its wine'})
# Out:
# 'Italy'

# %%
# 국가설명 -> 국가명 -> 해당 국가 수도명
final_chain = country_chain | capital_chain
final_chain.invoke({'information':'This country is very famous for its wine'})
# Out:
# 'Paris.'

# %%
# 국가설명 -> 국가명 -> 해당 국가 수도명
final_chain = {'country':country_chain} | capital_chain
final_chain.invoke({'information':'This country is very famous for its wine'})
# Out:
# 'Rome'

# %%
final_chain.invoke({'information':'와인으로 유명해요'})
# Out:
# 'Rome'

# %% [markdown]
# LLM호출 : ChatOllama(llama3.2:1b / exaone3.5:2.4b), ChatOpenAI
# LLM 호출에 필요한 프롬프트 템플릿 : PromptTemplate, ChatPromptTemplate(few shot, 페르소나설정)
# LLM 결과를 변환 outputParser : str/JSON/pydentic 클래스 생성하여 LLM의 Structed outputParser 이용
# 위 모두 runnable로부터 상속받은 invoke 가능 => LangChain으로 연결 가능 (=>RAG)
# # 5. 생성형 AI 평가 :
# - 첫번째 체인 : 나라이름 -> 그 나라에서 가장 유명한 음식
# - 두번째 체인 : 음식 -> 음식의 레시피
# - 최종 체인 : 나라이름 -> 그 나라에 가장 유명한 음식의 레시피
