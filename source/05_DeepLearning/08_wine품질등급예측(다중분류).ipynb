# %%
from IPython.display import display, HTML

display(HTML("""
<style>

/* =========================
   전체 레이아웃
========================= */

div.container{
    width:85% !important;
}

div.cell.code_cell.rendered{
    width:100%;
}

div.input_prompt{
    padding:0;
}

div.prompt{
    min-width:70px;
}

div#toc-wrapper{
    padding-top:120px;
}

table.dataframe{
    font-size:12px;
}

/* =========================
   코드 입력창
========================= */

div.CodeMirror{
    font-family:"마루 부리OTF 중간" !important;
    font-size:12pt !important;
    line-height:1.6;
}

/* =========================
   입력 셀
========================= */

div.input{
    font-family:"마루 부리OTF 중간" !important;
    font-size:12pt !important;
}

/* =========================
   코드 출력
========================= */

div.output{
    font-family:"마루 부리OTF 중간" !important;
    font-size:12pt !important;
}

/* =========================
   Markdown 전체
========================= */

.rendered_html{
    font-family:"마루 부리OTF 중간" !important;
    font-size:18px !important;
    line-height:1.8;
}

/* 제목 */
.rendered_html h1,
.rendered_html h2,
.rendered_html h3,
.rendered_html h4,
.rendered_html h5,
.rendered_html h6{
    font-family:"마루 부리OTF 조금굵은" !important;
}

/* 본문 */
.rendered_html p{
    font-family:"마루 부리OTF 중간" !important;
}

/* 리스트 */
.rendered_html li{
    font-family:"마루 부리OTF 중간" !important;
    padding:5px;
}

/* 인용 */
.rendered_html blockquote{
    font-family:"마루 부리OTF 중간" !important;
}

/* 표 */
.rendered_html table{
    font-family:"마루 부리OTF 중간" !important;
}

/* 코드 블록 */
.rendered_html pre,
.rendered_html code{
    font-family:"Consolas" !important;
    font-size:12pt !important;
}

</style>
"""))
# Out:
# <style>
#
# /* =========================
#    전체 레이아웃
# ========================= */
#
# div.container{
#     width:85% !important;
# }
#
# div.cell.code_cell.rendered{
#     width:100%;
# }
#
# div.input_prompt{
#     padding:0;
# }
#
# div.prompt{
#     min-width:70px;
# }
#
# div#toc-wrapper{
#     padding-top:120px;
# }
#
# table.dataframe{
#     font-size:12px;
# }
#
# /* =========================
#    코드 입력창
# ========================= */
#
# div.CodeMirror{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:12pt !important;
#     line-height:1.6;
# }
#
# /* =========================
#    입력 셀
# ========================= */
#
# div.input{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:12pt !important;
# }
#
# /* =========================
#    코드 출력
# ========================= */
#
# div.output{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:12pt !important;
# }
#
# /* =========================
#    Markdown 전체
# ========================= */
#
# .rendered_html{
#     font-family:"마루 부리OTF 중간" !important;
#     font-size:18px !important;
#     line-height:1.8;
# }
#
# /* 제목 */
# .rendered_html h1,
# .rendered_html h2,
# .rendered_html h3,
# .rendered_html h4,
# .rendered_html h5,
# .rendered_html h6{
#     font-family:"마루 부리OTF 조금굵은" !important;
# }
#
# /* 본문 */
# .rendered_html p{
#     font-family:"마루 부리OTF 중간" !important;
# }
#
# /* 리스트 */
# .rendered_html li{
#     font-family:"마루 부리OTF 중간" !important;
#     padding:5px;
# }
#
# /* 인용 */
# .rendered_html blockquote{
#     font-family:"마루 부리OTF 중간" !important;
# }
#
# /* 표 */
# .rendered_html table{
#     font-family:"마루 부리OTF 중간" !important;
# }
#
# /* 코드 블록 */
# .rendered_html pre,
# .rendered_html code{
#     font-family:"Consolas" !important;
#     font-size:12pt !important;
# }
#
# </style>

# %% [markdown]
# # red wine 품질 등급 예측
# 1. 데이터 셋 확보 & 전처리
#     결측치 처리 -> 독립(입력)변수와 종속(타겟)변수를 분리 -> 독립변수의 스케일조정(StandardScaler)
#     -> 종속변수의 균형을 확인
#     -> 종속변수 원핫인코딩(pd.get_dummies) -> 훈련셋과 테스트셋분리(train_test_split)
# 2. 모델구성
# 3. 모델학습과정 설정(다중분류)
# 4. 모델학습(callbacks, compute_class_weight를 이용)
# 5. 모델 평가(시각화, 평가, 교차표 - 테스트셋)
# 6. 모델 저장/예측

# %% [markdown]
# # 1. 데이터셋 확보 및 전처리

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.regularizers import l2
from tensorflow.keras import metrics # metrics.Recall, metrics.Precision
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback, ReduceLROnPlateau
from matplotlib import pyplot as plt

# %%
redwine = pd.read_csv('data/winequality-red.csv', sep=';')
redwine.info() # 결측치 없음
# redwine = np.loadtxt('data/winequality-red.csv', delimiter=';', skiprows=1) 넘파이배열로
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# 독립(입력)변수와 종속(타겟)변수를 분리
X_redwine = redwine.iloc[:, :-1].to_numpy() #.values과 유사. numpy로 변경
y_redwine = redwine.iloc[:, -1]#.values
X_redwine.shape, y_redwine.shape
# Out:
# ((1599, 11), (1599,))

# %%
# 독립변수의 스케일조정
scaler = StandardScaler()
# scaler.fit(X_redwine)
# scaled_X_redwine = scaler.transform(X_redwine)
scaled_X_redwine = scaler.fit_transform(X_redwine)

# %%
# 종속변수의 원핫인코딩
Y_redwine = pd.get_dummies(y_redwine).values
np.c_[y_redwine[2:4], Y_redwine[2:4]] # 원데이터와 원핫인코딩
# Out:
# array([[5, 0, 0, 1, 0, 0, 0],
#        [6, 0, 0, 0, 1, 0, 0]], dtype=int64)

# %%
# 종속변수의 균형을 확인
y_redwine.value_counts(normalize=True)
# Out:
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 4    0.033146
# 8    0.011257
# 3    0.006254
# Name: quality, dtype: float64

# %%
# 독립변수와 타겟변수
scaled_X_redwine.shape, Y_redwine.shape
# Out:
# ((1599, 11), (1599, 6))

# %%
# 훈련셋과 테스트셋 분리(층화추출) = 7 : 3
X_train, X_test, Y_train, Y_test = train_test_split(scaled_X_redwine,
                                                   Y_redwine,
                                                   test_size=0.3,
                                                   #train_size=0.7,
                                                   stratify=Y_redwine, # 층화추출
                                                   random_state=12) # seed값
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((1119, 11), (480, 11), (1119, 6), (480, 6))

# %% [markdown]
# # 2. 모델구성
# - 입력 11 -> 64 -> 50 -> 30 -> 출력 6
# - He초기화 : 층이 깊을 때 활성화함수를 relu사용시

# %%
model = Sequential(name='sequential')
model.add(Input(11))
model.add(Dense(units=64, activation='relu', kernel_initializer=HeNormal(seed=42)))
model.add(Dense(units=50, activation='relu', kernel_initializer='he_normal'))
model.add(Dropout(0.1))
model.add(Dense(units=30, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(units=6, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 50)                3250
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_2 (Dense)             (None, 30)                1530
#
#  dense_3 (Dense)             (None, 6)                 186
#
# =================================================================
# Total params: 5,734
# Trainable params: 5,734
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. 학습과정 설정

# %%
model.compile(loss='categorical_crossentropy', # sparse_categorical_crossentropy
             optimizer='adam',
             metrics=['accuracy', 
                      metrics.Recall(name='recall'), 
                      metrics.Precision(name='precision')])

# %% [markdown]
# # 4. 학습시키기
# - callbacks 이용

# %%
# %%time
earlyStopping = EarlyStopping(monitor='val_loss', patience=50)
hist = model.fit(X_train, Y_train,
                validation_split=0.2, # 학습셋의 20%를 검증셋으로
                # class_weight=class_weight_dict,
                callbacks=[earlyStopping],
                epochs=200, 
                verbose=2)
# Out:
# Epoch 1/200
# 28/28 - 2s - loss: 1.9233 - accuracy: 0.2492 - recall: 0.0547 - precision: 0.1769 - val_loss: 1.4983 - val_accuracy: 0.4062 - val_recall: 0.0982 - val_precision: 0.3438 - 2s/epoch - 56ms/step
# Epoch 2/200
# 28/28 - 0s - loss: 1.2572 - accuracy: 0.4659 - recall: 0.1587 - precision: 0.4863 - val_loss: 1.2915 - val_accuracy: 0.4777 - val_recall: 0.2232 - val_precision: 0.6757 - 81ms/epoch - 3ms/step
# Epoch 3/200
# 28/28 - 0s - loss: 1.1124 - accuracy: 0.5553 - recall: 0.2749 - precision: 0.6029 - val_loss: 1.1940 - val_accuracy: 0.5268 - val_recall: 0.3125 - val_precision: 0.6863 - 124ms/epoch - 4ms/step
# Epoch 4/200
# 28/28 - 0s - loss: 1.0452 - accuracy: 0.5765 - recall: 0.3698 - precision: 0.6440 - val_loss: 1.1435 - val_accuracy: 0.5312 - val_recall: 0.3661 - val_precision: 0.6212 - 133ms/epoch - 5ms/step
# Epoch 5/200
# 28/28 - 0s - loss: 1.0186 - accuracy: 0.5911 - recall: 0.4089 - precision: 0.6343 - val_loss: 1.1197 - val_accuracy: 0.5357 - val_recall: 0.4018 - val_precision: 0.6250 - 102ms/epoch - 4ms/step
# Epoch 6/200
# 28/28 - 0s - loss: 0.9851 - accuracy: 0.5978 - recall: 0.4335 - precision: 0.6434 - val_loss: 1.1070 - val_accuracy: 0.5357 - val_recall: 0.4464 - val_precision: 0.6289 - 124ms/epoch - 4ms/step
# Epoch 7/200
# 28/28 - 0s - loss: 0.9379 - accuracy: 0.6179 - recall: 0.4950 - precision: 0.6784 - val_loss: 1.0750 - val_accuracy: 0.5446 - val_recall: 0.4509 - val_precision: 0.6433 - 114ms/epoch - 4ms/step
# Epoch 8/200
# 28/28 - 0s - loss: 0.9264 - accuracy: 0.6179 - recall: 0.4849 - precision: 0.6596 - val_loss: 1.0772 - val_accuracy: 0.5357 - val_recall: 0.4420 - val_precision: 0.6266 - 146ms/epoch - 5ms/step
# Epoch 9/200
# 28/28 - 0s - loss: 0.9091 - accuracy: 0.6268 - recall: 0.4804 - precision: 0.6545 - val_loss: 1.0761 - val_accuracy: 0.5402 - val_recall: 0.4554 - val_precision: 0.6258 - 88ms/epoch - 3ms/step
# Epoch 10/200
# 28/28 - 0s - loss: 0.8998 - accuracy: 0.6302 - recall: 0.5330 - precision: 0.6671 - val_loss: 1.0527 - val_accuracy: 0.5714 - val_recall: 0.4732 - val_precision: 0.6503 - 96ms/epoch - 3ms/step
# Epoch 11/200
# 28/28 - 0s - loss: 0.8776 - accuracy: 0.6413 - recall: 0.5117 - precision: 0.6887 - val_loss: 1.0506 - val_accuracy: 0.5982 - val_recall: 0.4866 - val_precision: 0.6450 - 88ms/epoch - 3ms/step
# Epoch 12/200
# 28/28 - 0s - loss: 0.8668 - accuracy: 0.6536 - recall: 0.5263 - precision: 0.6937 - val_loss: 1.0431 - val_accuracy: 0.5625 - val_recall: 0.4643 - val_precision: 0.6190 - 92ms/epoch - 3ms/step
# Epoch 13/200
# 28/28 - 0s - loss: 0.8543 - accuracy: 0.6324 - recall: 0.5207 - precision: 0.6657 - val_loss: 1.0309 - val_accuracy: 0.6116 - val_recall: 0.5089 - val_precision: 0.6667 - 113ms/epoch - 4ms/step
# Epoch 14/200
# 28/28 - 0s - loss: 0.8391 - accuracy: 0.6581 - recall: 0.5665 - precision: 0.6945 - val_loss: 1.0446 - val_accuracy: 0.5848 - val_recall: 0.4911 - val_precision: 0.6250 - 94ms/epoch - 3ms/step
# Epoch 15/200
# 28/28 - 0s - loss: 0.8254 - accuracy: 0.6559 - recall: 0.5620 - precision: 0.6976 - val_loss: 1.0362 - val_accuracy: 0.5848 - val_recall: 0.4911 - val_precision: 0.6111 - 88ms/epoch - 3ms/step
# Epoch 16/200
# 28/28 - 0s - loss: 0.8245 - accuracy: 0.6503 - recall: 0.5575 - precision: 0.7108 - val_loss: 1.0251 - val_accuracy: 0.6116 - val_recall: 0.5268 - val_precision: 0.6743 - 97ms/epoch - 3ms/step
# Epoch 17/200
# 28/28 - 0s - loss: 0.8195 - accuracy: 0.6603 - recall: 0.5832 - precision: 0.6988 - val_loss: 1.0127 - val_accuracy: 0.5893 - val_recall: 0.5089 - val_precision: 0.6514 - 84ms/epoch - 3ms/step
# Epoch 18/200
# 28/28 - 0s - loss: 0.7903 - accuracy: 0.6536 - recall: 0.5698 - precision: 0.7113 - val_loss: 1.0556 - val_accuracy: 0.5670 - val_recall: 0.5045 - val_precision: 0.6175 - 85ms/epoch - 3ms/step
# Epoch 19/200
# 28/28 - 0s - loss: 0.7953 - accuracy: 0.6626 - recall: 0.5877 - precision: 0.7032 - val_loss: 1.0276 - val_accuracy: 0.6027 - val_recall: 0.5179 - val_precision: 0.6480 - 85ms/epoch - 3ms/step
# Epoch 20/200
# 28/28 - 0s - loss: 0.7868 - accuracy: 0.6760 - recall: 0.5978 - precision: 0.7086 - val_loss: 1.0263 - val_accuracy: 0.5893 - val_recall: 0.5357 - val_precision: 0.6383 - 116ms/epoch - 4ms/step
# Epoch 21/200
# 28/28 - 0s - loss: 0.7828 - accuracy: 0.6793 - recall: 0.5955 - precision: 0.7032 - val_loss: 1.0406 - val_accuracy: 0.5759 - val_recall: 0.5268 - val_precision: 0.6178 - 105ms/epoch - 4ms/step
# Epoch 22/200
# 28/28 - 0s - loss: 0.7623 - accuracy: 0.6693 - recall: 0.6022 - precision: 0.7055 - val_loss: 1.0017 - val_accuracy: 0.6116 - val_recall: 0.5223 - val_precision: 0.6464 - 127ms/epoch - 5ms/step
# Epoch 23/200
# 28/28 - 0s - loss: 0.7723 - accuracy: 0.6704 - recall: 0.5955 - precision: 0.7013 - val_loss: 1.0297 - val_accuracy: 0.5938 - val_recall: 0.5312 - val_precision: 0.6432 - 127ms/epoch - 5ms/step
# Epoch 24/200
# 28/28 - 0s - loss: 0.7513 - accuracy: 0.6715 - recall: 0.6011 - precision: 0.7033 - val_loss: 1.0292 - val_accuracy: 0.5982 - val_recall: 0.5357 - val_precision: 0.6218 - 118ms/epoch - 4ms/step
# Epoch 25/200
# 28/28 - 0s - loss: 0.7499 - accuracy: 0.6849 - recall: 0.6134 - precision: 0.7252 - val_loss: 1.0453 - val_accuracy: 0.5893 - val_recall: 0.5134 - val_precision: 0.6085 - 96ms/epoch - 3ms/step
# Epoch 26/200
# 28/28 - 0s - loss: 0.7318 - accuracy: 0.6872 - recall: 0.6246 - precision: 0.7232 - val_loss: 1.0309 - val_accuracy: 0.5982 - val_recall: 0.5179 - val_precision: 0.6073 - 95ms/epoch - 3ms/step
# Epoch 27/200
# 28/28 - 0s - loss: 0.7342 - accuracy: 0.6905 - recall: 0.6168 - precision: 0.7235 - val_loss: 1.0503 - val_accuracy: 0.6027 - val_recall: 0.5268 - val_precision: 0.6310 - 91ms/epoch - 3ms/step
# Epoch 28/200
# 28/28 - 0s - loss: 0.7270 - accuracy: 0.6782 - recall: 0.6179 - precision: 0.7248 - val_loss: 1.0325 - val_accuracy: 0.5893 - val_recall: 0.5536 - val_precision: 0.6263 - 91ms/epoch - 3ms/step
# Epoch 29/200
# 28/28 - 0s - loss: 0.7187 - accuracy: 0.6950 - recall: 0.6268 - precision: 0.7239 - val_loss: 1.0321 - val_accuracy: 0.6027 - val_recall: 0.5312 - val_precision: 0.6263 - 78ms/epoch - 3ms/step
# Epoch 30/200
# 28/28 - 0s - loss: 0.7140 - accuracy: 0.6916 - recall: 0.6369 - precision: 0.7383 - val_loss: 1.0383 - val_accuracy: 0.5938 - val_recall: 0.5491 - val_precision: 0.6308 - 79ms/epoch - 3ms/step
# Epoch 31/200
# 28/28 - 0s - loss: 0.7017 - accuracy: 0.7039 - recall: 0.6380 - precision: 0.7283 - val_loss: 1.0348 - val_accuracy: 0.5938 - val_recall: 0.5446 - val_precision: 0.6224 - 82ms/epoch - 3ms/step
# Epoch 32/200
# 28/28 - 0s - loss: 0.6969 - accuracy: 0.7017 - recall: 0.6324 - precision: 0.7266 - val_loss: 1.0484 - val_accuracy: 0.5848 - val_recall: 0.5446 - val_precision: 0.6321 - 137ms/epoch - 5ms/step
# Epoch 33/200
# 28/28 - 0s - loss: 0.6938 - accuracy: 0.7039 - recall: 0.6391 - precision: 0.7277 - val_loss: 1.0495 - val_accuracy: 0.6161 - val_recall: 0.5580 - val_precision: 0.6443 - 138ms/epoch - 5ms/step
# Epoch 34/200
# 28/28 - 0s - loss: 0.6880 - accuracy: 0.7017 - recall: 0.6503 - precision: 0.7405 - val_loss: 1.0397 - val_accuracy: 0.5893 - val_recall: 0.5491 - val_precision: 0.6244 - 105ms/epoch - 4ms/step
# Epoch 35/200
# 28/28 - 0s - loss: 0.6910 - accuracy: 0.7106 - recall: 0.6603 - precision: 0.7314 - val_loss: 1.0422 - val_accuracy: 0.5848 - val_recall: 0.5446 - val_precision: 0.6289 - 91ms/epoch - 3ms/step
# Epoch 36/200
# 28/28 - 0s - loss: 0.6718 - accuracy: 0.7128 - recall: 0.6570 - precision: 0.7500 - val_loss: 1.0308 - val_accuracy: 0.5759 - val_recall: 0.5491 - val_precision: 0.6308 - 110ms/epoch - 4ms/step
# Epoch 37/200
# 28/28 - 0s - loss: 0.6641 - accuracy: 0.7184 - recall: 0.6592 - precision: 0.7564 - val_loss: 1.0846 - val_accuracy: 0.6161 - val_recall: 0.5580 - val_precision: 0.6158 - 89ms/epoch - 3ms/step
# Epoch 38/200
# 28/28 - 0s - loss: 0.6583 - accuracy: 0.7162 - recall: 0.6715 - precision: 0.7475 - val_loss: 1.0626 - val_accuracy: 0.5938 - val_recall: 0.5536 - val_precision: 0.6231 - 92ms/epoch - 3ms/step
# Epoch 39/200
# 28/28 - 0s - loss: 0.6401 - accuracy: 0.7207 - recall: 0.6760 - precision: 0.7610 - val_loss: 1.0758 - val_accuracy: 0.6116 - val_recall: 0.5804 - val_precision: 0.6341 - 75ms/epoch - 3ms/step
# Epoch 40/200
# 28/28 - 0s - loss: 0.6279 - accuracy: 0.7296 - recall: 0.6872 - precision: 0.7593 - val_loss: 1.0490 - val_accuracy: 0.6161 - val_recall: 0.5670 - val_precision: 0.6480 - 88ms/epoch - 3ms/step
# Epoch 41/200
# 28/28 - 0s - loss: 0.6367 - accuracy: 0.7274 - recall: 0.6860 - precision: 0.7733 - val_loss: 1.0537 - val_accuracy: 0.5982 - val_recall: 0.5625 - val_precision: 0.6429 - 110ms/epoch - 4ms/step
# Epoch 42/200
# 28/28 - 0s - loss: 0.6384 - accuracy: 0.7385 - recall: 0.6927 - precision: 0.7702 - val_loss: 1.0448 - val_accuracy: 0.6339 - val_recall: 0.5804 - val_precision: 0.6633 - 82ms/epoch - 3ms/step
# Epoch 43/200
# 28/28 - 0s - loss: 0.6187 - accuracy: 0.7453 - recall: 0.6883 - precision: 0.7719 - val_loss: 1.0579 - val_accuracy: 0.6295 - val_recall: 0.5670 - val_precision: 0.6480 - 80ms/epoch - 3ms/step
# Epoch 44/200
# 28/28 - 0s - loss: 0.6165 - accuracy: 0.7240 - recall: 0.6860 - precision: 0.7694 - val_loss: 1.0476 - val_accuracy: 0.6071 - val_recall: 0.5580 - val_precision: 0.6345 - 93ms/epoch - 3ms/step
# Epoch 45/200
# 28/28 - 0s - loss: 0.6020 - accuracy: 0.7486 - recall: 0.7017 - precision: 0.7811 - val_loss: 1.0820 - val_accuracy: 0.6116 - val_recall: 0.5804 - val_precision: 0.6404 - 84ms/epoch - 3ms/step
# Epoch 46/200
# 28/28 - 0s - loss: 0.5958 - accuracy: 0.7419 - recall: 0.7028 - precision: 0.7708 - val_loss: 1.0857 - val_accuracy: 0.6071 - val_recall: 0.5536 - val_precision: 0.6327 - 85ms/epoch - 3ms/step
# Epoch 47/200
# 28/28 - 0s - loss: 0.5876 - accuracy: 0.7453 - recall: 0.7084 - precision: 0.7789 - val_loss: 1.0712 - val_accuracy: 0.6161 - val_recall: 0.5580 - val_precision: 0.6378 - 85ms/epoch - 3ms/step
# Epoch 48/200
# 28/28 - 0s - loss: 0.5872 - accuracy: 0.7475 - recall: 0.7028 - precision: 0.7737 - val_loss: 1.0861 - val_accuracy: 0.6071 - val_recall: 0.5714 - val_precision: 0.6400 - 95ms/epoch - 3ms/step
# Epoch 49/200
# 28/28 - 0s - loss: 0.5830 - accuracy: 0.7587 - recall: 0.7296 - precision: 0.7925 - val_loss: 1.1202 - val_accuracy: 0.5938 - val_recall: 0.5491 - val_precision: 0.6308 - 86ms/epoch - 3ms/step
# Epoch 50/200
# 28/28 - 0s - loss: 0.5900 - accuracy: 0.7531 - recall: 0.7061 - precision: 0.7812 - val_loss: 1.1140 - val_accuracy: 0.5982 - val_recall: 0.5536 - val_precision: 0.6294 - 104ms/epoch - 4ms/step
# Epoch 51/200
# 28/28 - 0s - loss: 0.5723 - accuracy: 0.7575 - recall: 0.7184 - precision: 0.7880 - val_loss: 1.1205 - val_accuracy: 0.5982 - val_recall: 0.5670 - val_precision: 0.6382 - 128ms/epoch - 5ms/step
# Epoch 52/200
# 28/28 - 0s - loss: 0.5548 - accuracy: 0.7810 - recall: 0.7363 - precision: 0.8086 - val_loss: 1.1090 - val_accuracy: 0.5938 - val_recall: 0.5670 - val_precision: 0.6318 - 90ms/epoch - 3ms/step
# Epoch 53/200
# 28/28 - 0s - loss: 0.5617 - accuracy: 0.7754 - recall: 0.7385 - precision: 0.8061 - val_loss: 1.1374 - val_accuracy: 0.5759 - val_recall: 0.5491 - val_precision: 0.6059 - 118ms/epoch - 4ms/step
# Epoch 54/200
# 28/28 - 0s - loss: 0.5546 - accuracy: 0.7609 - recall: 0.7318 - precision: 0.7892 - val_loss: 1.1455 - val_accuracy: 0.6161 - val_recall: 0.5759 - val_precision: 0.6324 - 138ms/epoch - 5ms/step
# Epoch 55/200
# 28/28 - 0s - loss: 0.5477 - accuracy: 0.7754 - recall: 0.7385 - precision: 0.8071 - val_loss: 1.1211 - val_accuracy: 0.5893 - val_recall: 0.5625 - val_precision: 0.6176 - 138ms/epoch - 5ms/step
# Epoch 56/200
# 28/28 - 0s - loss: 0.5563 - accuracy: 0.7609 - recall: 0.7207 - precision: 0.8002 - val_loss: 1.1494 - val_accuracy: 0.5938 - val_recall: 0.5714 - val_precision: 0.6154 - 96ms/epoch - 3ms/step
# Epoch 57/200
# 28/28 - 0s - loss: 0.5450 - accuracy: 0.7866 - recall: 0.7486 - precision: 0.8072 - val_loss: 1.1277 - val_accuracy: 0.5714 - val_recall: 0.5402 - val_precision: 0.6142 - 88ms/epoch - 3ms/step
# Epoch 58/200
# 28/28 - 0s - loss: 0.5519 - accuracy: 0.7698 - recall: 0.7274 - precision: 0.7949 - val_loss: 1.1258 - val_accuracy: 0.5982 - val_recall: 0.5714 - val_precision: 0.6337 - 100ms/epoch - 4ms/step
# Epoch 59/200
# 28/28 - 0s - loss: 0.5494 - accuracy: 0.7687 - recall: 0.7318 - precision: 0.7949 - val_loss: 1.1494 - val_accuracy: 0.5848 - val_recall: 0.5580 - val_precision: 0.5952 - 103ms/epoch - 4ms/step
# Epoch 60/200
# 28/28 - 0s - loss: 0.5384 - accuracy: 0.7765 - recall: 0.7330 - precision: 0.8010 - val_loss: 1.1230 - val_accuracy: 0.6027 - val_recall: 0.5491 - val_precision: 0.6181 - 76ms/epoch - 3ms/step
# Epoch 61/200
# 28/28 - 0s - loss: 0.5084 - accuracy: 0.7866 - recall: 0.7564 - precision: 0.8118 - val_loss: 1.1530 - val_accuracy: 0.6205 - val_recall: 0.5938 - val_precision: 0.6333 - 66ms/epoch - 2ms/step
# Epoch 62/200
# 28/28 - 0s - loss: 0.5218 - accuracy: 0.7821 - recall: 0.7453 - precision: 0.8046 - val_loss: 1.1216 - val_accuracy: 0.6027 - val_recall: 0.5670 - val_precision: 0.6225 - 68ms/epoch - 2ms/step
# Epoch 63/200
# 28/28 - 0s - loss: 0.5427 - accuracy: 0.7844 - recall: 0.7497 - precision: 0.8114 - val_loss: 1.1353 - val_accuracy: 0.5893 - val_recall: 0.5491 - val_precision: 0.6029 - 68ms/epoch - 2ms/step
# Epoch 64/200
# 28/28 - 0s - loss: 0.5060 - accuracy: 0.7933 - recall: 0.7531 - precision: 0.8190 - val_loss: 1.1509 - val_accuracy: 0.5714 - val_recall: 0.5491 - val_precision: 0.5942 - 106ms/epoch - 4ms/step
# Epoch 65/200
# 28/28 - 0s - loss: 0.5072 - accuracy: 0.8034 - recall: 0.7620 - precision: 0.8237 - val_loss: 1.1703 - val_accuracy: 0.6071 - val_recall: 0.5759 - val_precision: 0.6114 - 115ms/epoch - 4ms/step
# Epoch 66/200
# 28/28 - 0s - loss: 0.5132 - accuracy: 0.7855 - recall: 0.7542 - precision: 0.7998 - val_loss: 1.1526 - val_accuracy: 0.5893 - val_recall: 0.5625 - val_precision: 0.6146 - 95ms/epoch - 3ms/step
# Epoch 67/200
# 28/28 - 0s - loss: 0.5115 - accuracy: 0.7799 - recall: 0.7419 - precision: 0.8048 - val_loss: 1.1707 - val_accuracy: 0.5982 - val_recall: 0.5625 - val_precision: 0.6176 - 84ms/epoch - 3ms/step
# Epoch 68/200
# 28/28 - 0s - loss: 0.5058 - accuracy: 0.8056 - recall: 0.7732 - precision: 0.8268 - val_loss: 1.1856 - val_accuracy: 0.5982 - val_recall: 0.5714 - val_precision: 0.6184 - 86ms/epoch - 3ms/step
# Epoch 69/200
# 28/28 - 0s - loss: 0.5003 - accuracy: 0.8000 - recall: 0.7609 - precision: 0.8225 - val_loss: 1.1630 - val_accuracy: 0.5848 - val_recall: 0.5580 - val_precision: 0.6127 - 84ms/epoch - 3ms/step
# Epoch 70/200
# 28/28 - 0s - loss: 0.4787 - accuracy: 0.8022 - recall: 0.7732 - precision: 0.8317 - val_loss: 1.1915 - val_accuracy: 0.6027 - val_recall: 0.5625 - val_precision: 0.6029 - 103ms/epoch - 4ms/step
# Epoch 71/200
# 28/28 - 0s - loss: 0.4924 - accuracy: 0.7978 - recall: 0.7743 - precision: 0.8134 - val_loss: 1.1906 - val_accuracy: 0.5625 - val_recall: 0.5446 - val_precision: 0.5894 - 100ms/epoch - 4ms/step
# Epoch 72/200
# 28/28 - 0s - loss: 0.4705 - accuracy: 0.8179 - recall: 0.7855 - precision: 0.8359 - val_loss: 1.1963 - val_accuracy: 0.5982 - val_recall: 0.5625 - val_precision: 0.6117 - 84ms/epoch - 3ms/step
# CPU times: total: 13.3 s
# Wall time: 9.08 s

# %% [markdown]
# # 5. 모델평가
# - 시각화, 평가, 교차표

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'recall', 'precision', 'val_loss', 'val_accuracy', 'val_recall', 'val_precision'])

# %%
# 학습과정 살펴보기(시각화)
fig, loss_ax = plt.subplots(figsize=(15,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')
acc_ax.plot(hist.history['val_recall'], 'k', label='val_accuracy')
acc_ax.plot(hist.history['val_precision'], 'k', label='val_accuracy')

acc_ax.set_ylabel('accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(bbox_to_anchor=(0.97,0.75))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 평가
loss, acc, recall, precision = model.evaluate(X_test, Y_test, verbose=0)
print('정확도 :', acc)
print('재현율 :', recall)
print('정밀도 :', precision)
# Out:
# 정확도 : 0.6270833611488342
# 재현율 : 0.5895833373069763
# 정밀도 : 0.6417233347892761

# %%
# 교차표를 위한 y_hat
y_hat = model.predict(X_test).argmax(axis=1) + 3 # 예측값
y = Y_test.argmax(axis=1) + 3 # 실제값
pd.crosstab(y, y_hat, rownames=['실제'], colnames=['예측'])
# Out:
# 15/15 [==============================] - 0s 2ms/step
# 예측  3  4    5    6   7  8
# 실제
# 3   0  0    2    1   0  0
# 4   1  0    9    5   1  0
# 5   1  2  140   56   5  0
# 6   0  0   47  124  20  1
# 7   0  0    4   19  37  0
# 8   0  0    0    1   4  0

# %% [markdown]
# # 6. 모델 사용

# %%
X_redwine[0]
# Out:
# array([ 7.4   ,  0.7   ,  0.    ,  1.9   ,  0.076 , 11.    , 34.    ,
#         0.9978,  3.51  ,  0.56  ,  9.4   ])

# %%
data = [[ 7.4,0.7, 0.,  1.9,  0.076, 11., 34. , 0.9978,  3.51  ,  0.56  ,  9.4   ]]
input_data = scaler.transform(data)
model.predict(input_data).argmax(axis=1)+3
# Out:
# 1/1 [==============================] - 0s 103ms/step
# array([5], dtype=int64)
